# %% [markdown]
# <a href="https://colab.research.google.com/github/irbaadika/PVCK_Genap_2023/blob/main/Jobsheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/ASSETS-PVCK/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # Konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/ASSETS-PVCK/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# Simpan file image
# cv.imwrite('/content/drive/MyDrive/ASSETS-PVCK/Images/mandrill2.tiff', img5)

# Tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) # Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# Perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # Nilai 2 untuk menunjukkan bahw tiap titik dibuat 3 channel yang mewakili nilai R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **PERTANYAAN**
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# Jawab : jika tampa matplotlib gambar yang ditampilkan adalah gambar saja tanpa ada garis ordinat disebelah kiri dan bawah, sedangkan jika menggunakan matplotlib gambar yang muncul akan disertai dengan garis ordinat di sebelah kiri dan bawah
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# Jawab : berbeda ukuran tampungan dimana range nilai yang ditampung int16 lebih kecil dari pada range nilai int32 dan pengaruhnya jika akan mencetak sesuatu yang ada di int32 kemudian dicetak menggunakan int16 maka hasil akan tidak maksimal
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
# Jawab : untuk import cv_imshow (tampilkan gambar) pada package google colab
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
# Jawab : untuk ekstraksi fitur -> membaca dan manulis gambar di berbagai macam format

# %% [markdown]
# **TUGAS**
#
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah? Jawab : untuk ukuran pixel tidak berubah namun yang berubah adaah ukuran gambar yang ditampilkan
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-115, kolom 25-120!
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
# 6. Tampilkan image dengan posisi terbalik!
#
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/peppers!
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.
# 10. Tunjukkan code program anda pada bapak/ibu dosen

# %%
# TUGAS NO 2
# Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# RED-BLUE
redblue = img3 * [1, 0, 1]
plt.imshow(redblue)

# %%
# TUGAS NO 2
# Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# GREEN-BLUE
greenblue = img3 * [0, 1, 1]
plt.imshow(greenblue)

# %%
# TUGAS NO 3
# Tampilkan image baris ke 20-115, kolom 25-120!

plt.imshow(img3[20:115, 25:120])

# %%
# TUGAS NO 4
# Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

red = img3 * [1, 0, 0]
plt.imshow(red[5:30])

# %%
# TUGAS NO 5
# Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

img_10 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_10, pt1=(50,100), pt2=(100,150), color=(255,255,255), thickness=5)
cv.rectangle(img_10, pt1=(80,250), pt2=(250,300), color=(0,0,0), thickness=5)
cv.rectangle(img_10, pt1=(300,300), pt2=(400,450), color=(255,0,0), thickness=5)
cv.rectangle(img_10, pt1=(150,400), pt2=(500,550), color=(255,255,0), thickness=5)
cv.rectangle(img_10, pt1=(250,50), pt2=(300,250), color=(0,255,255), thickness=5)

plt.imshow(img_10)

# %%
#TUGAS NO 6
# Tampilkan image dengan posisi terbalik!

img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %%
# TUGAS NO 7
# Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

myimg = cv.imread('/content/drive/MyDrive/ASSETS-PVCK/Images/myimg.jpg')
myimg2 = cv.cvtColor(myimg, cv.COLOR_BGR2RGB)

fig = plt.figure(figsize=(10,10)) # Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)

cv.rectangle(myimg2, pt1=(380,615), pt2 = (475,725), color= (255,0,0), thickness=10)
cv.circle(myimg2, center=(427,667),radius=50, color=(0,255,255), thickness=10)

plt.imshow(myimg2)

# %%
# TUGAS NO 8
# Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB 
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/peppers!

lena = cv.imread('/content/drive/MyDrive/ASSETS-PVCK/Images/lena_lc.jpg')
lena_x = cv.cvtColor(lena, cv.COLOR_BGR2RGB)

tinggi = lena_x.shape[0]
lebar = lena_x.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)

cv.rectangle(lena_x, pt1=(0,450), pt2=(100,512), color=(255,255,255), thickness=5)

plt.imshow(lena_x)
# Out:
# resolusi image: tinggi x lebar =  512  x  512

# %%
# TUGAS NO 9
# Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, 
# ukuran font, dan warna font yang sesuai keinginan anda.

lena = cv.imread('/content/drive/MyDrive/ASSETS-PVCK/Images/lena_lc.jpg')
lenaf = cv.cvtColor(lena, cv.COLOR_BGR2RGB)

cv.rectangle(lenaf, pt1=(0,450), pt2=(100,512), color=(255,255,255), thickness=5)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(lenaf,text='LENA',org=(50,300),fontFace=font,fontScale=5,color=(255,0,0),thickness=4,lineType=cv.LINE_AA)
plt.imshow(lenaf)
